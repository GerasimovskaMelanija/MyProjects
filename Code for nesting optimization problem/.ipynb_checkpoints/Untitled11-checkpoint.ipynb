# %%
y[0]-min_y(koord_za_comp[0]) >= 0
y[1]-min_y(koord_za_comp[1]) >= 0
y[2]-min_y(koord_za_comp[2]) >= 0
y[3]-min_y(koord_za_comp[3]) >= 0
y[4]-min_y(koord_za_comp[4]) >= 0
y[5]-min_y(koord_za_comp[5]) >= 0
y[6]-min_y(koord_za_comp[6]) >= 0
y[7]-min_y(koord_za_comp[7]) >= 0
y[8]-min_y(koord_za_comp[8]) >= 0
y[9]-min_y(koord_za_comp[9]) >= 0
y[10]-min_y(koord_za_comp[10]) >= 0
y[11]-min_y(koord_za_comp[11]) >= 0
y[12]-min_y(koord_za_comp[12]) >= 0
y[13]-min_y(koord_za_comp[13]) >= 0
y[14]-min_y(koord_za_comp[14]) >= 0
y[15]-min_y(koord_za_comp[15]) >= 0
y[16]-min_y(koord_za_comp[16]) >= 0
y[17]-min_y(koord_za_comp[17]) >= 0
y[18]-min_y(koord_za_comp[18]) >= 0
y[19]-min_y(koord_za_comp[19]) >= 0
y[20]-min_y(koord_za_comp[20]) >= 0
y[21]-min_y(koord_za_comp[21]) >= 0
y[22]-min_y(koord_za_comp[22]) >= 0
y[23]-min_y(koord_za_comp[23]) >= 0


"""
for i in range(24):
    for j in range(24):
        if j == i:
            j= j+1
        pp[i] = Polygon

x11=[]
y11=[]
for m in range(len(x)):
    x11.append(x[m].bounds[0])
for m in range(len(y)):
    y11.append(y[m].bounds[0])
razlika1=[]
razlika2=[]
for i in range(len(x1)):
    razlika1.append(x1[i] - x11[i])
print(razlika1)
for i in range(len(y1)):
    razlika2.append(y1[i] - y11[i])
print(y1)
print(y11)
print(razlika2)
#pravime update na koordinatite i gledame dali se secat
    for k in range(len(koord_za_comp)):
    for m in range(len(koord_za_comp[k])):
        print(y11[k])
        if (y11[k] - min_y(koord_p[k])) >=0 :
            print('za y ',y11[k] - min_y(koord_p[k]))
            if(x11[k] - min_x(koord_p[k])) >= 0:
                print(x11[k] - min_x(koord_p[k]))
                koord_za_comp[k][m][0] = koord_za_comp[k][m][0] -razlika1[k]
                koord_za_comp[k][m][1] = koord_za_comp[k][m][1] -razlika2[k]
            else:
                x11[k] = x1[k]
                x[k] = x1[k]
                y11[k] = y1[k]
                y[k] = y1[k]
        else:
            y11[k] = y1[k]
            y[k] = y1[k]
            x11[k] = x1[k]
            x[k] = x1[k]
    pp.append(Polygon(koord_za_comp[k]))
if (pp[0].intersects(pp[1]) == False and pp[0].intersects(pp[2]) == False and pp[0].intersects(pp[3]) == False and pp[0].intersects(pp[4]) == False and pp[0].intersects(pp[5]) == False and pp[0].intersects(pp[6]) == False and pp[0].intersects(pp[7]) == False and pp[0].intersects(pp[8]) == False and pp[0].intersects(pp[9]) == False and pp[0].intersects(pp[10]) == False and pp[0].intersects(pp[11]) == False and pp[0].intersects(pp[12]) == False and pp[0].intersects(pp[13]) == False and pp[0].intersects(pp[14]) == False and pp[0].intersects(pp[15]) == False and pp[0].intersects(pp[16]) == False and pp[0].intersects(pp[17]) == False and pp[0].intersects(pp[18]) == False and pp[0].intersects(pp[19]) == False and pp[0].intersects(pp[20]) == False and pp[0].intersects(pp[21]) == False and pp[0].intersects(pp[22]) == False and pp[0].intersects(pp[23]) == False and
   pp[1].intersects(pp[2]) == False and pp[1].intersects(pp[3]) == False and pp[1].intersects(pp[4]) == False and pp[1].intersects(pp[5]) == False and pp[1].intersects(pp[6]) == False and pp[1].intersects(pp[7]) == False and pp[1].intersects(pp[8]) == False and pp[1].intersects(pp[9]) == False and pp[1].intersects(pp[10]) == False and pp[1].intersects(pp[11]) == False and pp[1].intersects(pp[12]) == False and pp[1].intersects(pp[13]) == False and pp[1].intersects(pp[14]) == False and pp[1].intersects(pp[15]) == False and pp[1].intersects(pp[16]) == False and pp[1].intersects(pp[17]) == False and pp[1].intersects(pp[18]) == False and pp[1].intersects(pp[19]) == False and pp[1].intersects(pp[20]) == False and pp[1].intersects(pp[21]) == False and pp[1].intersects(pp[22]) == False and pp[1].intersects(pp[23]) == False and
   pp[2].intersects(pp[3]) == False and pp[2].intersects(pp[4]) == False and pp[2].intersects(pp[5]) == False and pp[2].intersects(pp[6]) == False and pp[2].intersects(pp[7]) == False and pp[2].intersects(pp[8]) == False and pp[2].intersects(pp[9]) == False and pp[2].intersects(pp[10]) == False and pp[2].intersects(pp[11]) == False and pp[2].intersects(pp[12]) == False and pp[2].intersects(pp[13]) == False and pp[2].intersects(pp[14]) == False and pp[2].intersects(pp[15]) == False and pp[2].intersects(pp[16]) == False and pp[2].intersects(pp[17]) == False and pp[2].intersects(pp[18]) == False and pp[2].intersects(pp[19]) == False and pp[2].intersects(pp[20]) == False and pp[2].intersects(pp[21]) == False and pp[2].intersects(pp[22]) == False and pp[2].intersects(pp[23]) == False and 
   pp[3].intersects(pp[4]) == False and pp[3].intersects(pp[5]) == False and pp[3].intersects(pp[6]) == False and pp[3].intersects(pp[7]) == False and pp[3].intersects(pp[8]) == False and pp[3].intersects(pp[9]) == False and pp[3].intersects(pp[10]) == False and pp[3].intersects(pp[11]) == False and pp[3].intersects(pp[12]) == False and pp[3].intersects(pp[13]) == False and pp[3].intersects(pp[14]) == False and  pp[3].intersects(pp[15]) == False and pp[3].intersects(pp[16]) == False and pp[3].intersects(pp[17]) == False and pp[3].intersects(pp[18]) == False and pp[3].intersects(pp[19]) == False and pp[3].intersects(pp[20]) == False and pp[3].intersects(pp[21]) == False and pp[3].intersects(pp[22]) == False and pp[3].intersects(pp[23]) == False and
   pp[4].intersects(pp[5]) == False and pp[4].intersects(pp[6]) == False and pp[4].intersects(pp[7]) == False and pp[4].intersects(pp[8]) == False and pp[4].intersects(pp[9]) == False and pp[4].intersects(pp[10]) == False and pp[4].intersects(pp[11]) == False and pp[4].intersects(pp[12]) == False and pp[4].intersects(pp[13]) == False and pp[4].intersects(pp[14]) == False and  pp[4].intersects(pp[15]) == False and pp[4].intersects(pp[16]) == False and pp[4].intersects(pp[17]) == False and pp[4].intersects(pp[18]) == False and pp[4].intersects(pp[19]) == False and pp[4].intersects(pp[20]) == False and pp[4].intersects(pp[21]) == False and pp[4].intersects(pp[22]) == False and pp[4].intersects(pp[23]) == False and
   pp[5].intersects(pp[6]) == False and pp[5].intersects(pp[7]) == False and pp[5].intersects(pp[8]) == False and pp[5].intersects(pp[9]) == False and pp[5].intersects(pp[10]) == False and pp[5].intersects(pp[11]) == False and pp[5].intersects(pp[12]) == False and pp[5].intersects(pp[13]) == False and pp[5].intersects(pp[14]) == False and  pp[5].intersects(pp[15]) == False and pp[5].intersects(pp[16]) == False and pp[5].intersects(pp[17]) == False and pp[5].intersects(pp[18]) == False and pp[5].intersects(pp[19]) == False and pp[5].intersects(pp[20]) == False and pp[5].intersects(pp[21]) == False and pp[5].intersects(pp[22]) == False and pp[5].intersects(pp[23]) == False and
   pp[6].intersects(pp[7]) == False and pp[6].intersects(pp[8]) == False and pp[6].intersects(pp[9]) == False and pp[6].intersects(pp[10]) == False and pp[6].intersects(pp[11]) == False and pp[6].intersects(pp[12]) == False and pp[6].intersects(pp[13]) == False and pp[6].intersects(pp[14]) == False and  pp[6].intersects(pp[15]) == False and pp[6].intersects(pp[16]) == False and pp[6].intersects(pp[17]) == False and pp[6].intersects(pp[18]) == False and pp[6].intersects(pp[19]) == False and pp[6].intersects(pp[20]) == False and pp[6].intersects(pp[21]) == False and pp[6].intersects(pp[22]) == False and pp[6].intersects(pp[23]) == False and
   pp[7].intersects(pp[8]) == False and pp[7].intersects(pp[9]) == False and pp[7].intersects(pp[10]) == False and pp[7].intersects(pp[11]) == False and pp[7].intersects(pp[12]) == False and pp[7].intersects(pp[13]) == False and pp[7].intersects(pp[14]) == False and  pp[7].intersects(pp[15]) == False and pp[7].intersects(pp[16]) == False and pp[7].intersects(pp[17]) == False and pp[7].intersects(pp[18]) == False and pp[6].intersects(pp[19]) == False and pp[7].intersects(pp[20]) == False and pp[7].intersects(pp[21]) == False and pp[7].intersects(pp[22]) == False and pp[7].intersects(pp[23]) == False and
   pp[8].intersects(pp[9]) == False and pp[8].intersects(pp[10]) == False and pp[8].intersects(pp[11]) == False and pp[8].intersects(pp[12]) == False and pp[8].intersects(pp[13]) == False and pp[8].intersects(pp[14]) == False and  pp[8].intersects(pp[15]) == False and pp[8].intersects(pp[16]) == False and pp[8].intersects(pp[17]) == False and pp[8].intersects(pp[18]) == False and pp[8].intersects(pp[19]) == False and pp[8].intersects(pp[20]) == False and pp[8].intersects(pp[21]) == False and pp[8].intersects(pp[22]) == False and pp[8].intersects(pp[23]) == False and
   pp[9].intersects(pp[10]) == False and pp[9].intersects(pp[11]) == False and pp[9].intersects(pp[12]) == False and pp[9].intersects(pp[13]) == False and pp[9].intersects(pp[14]) == False and  pp[9].intersects(pp[15]) == False and pp[9].intersects(pp[16]) == False and pp[9].intersects(pp[17]) == False and pp[9].intersects(pp[18]) == False and pp[9].intersects(pp[19]) == False and pp[9].intersects(pp[20]) == False and pp[9].intersects(pp[21]) == False and pp[9].intersects(pp[22]) == False and pp[9].intersects(pp[23]) == False and
   pp[10].intersects(pp[11]) == False and pp[10].intersects(pp[12]) == False and pp[10].intersects(pp[13]) == False and pp[10].intersects(pp[14]) == False and  pp[10].intersects(pp[15]) == False and pp[10].intersects(pp[16]) == False and pp[10].intersects(pp[17]) == False and pp[10].intersects(pp[18]) == False and pp[10].intersects(pp[19]) == False and pp[10].intersects(pp[20]) == False and pp[10].intersects(pp[21]) == False and pp[10].intersects(pp[22]) == False and pp[10].intersects(pp[23]) == False and
   pp[11].intersects(pp[12]) == False and pp[11].intersects(pp[13]) == False and pp[11].intersects(pp[14]) == False and pp[11].intersects(pp[15]) == False and pp[11].intersects(pp[16]) == False and pp[11].intersects(pp[17]) == False and pp[11].intersects(pp[18]) == False and pp[11].intersects(pp[19]) == False and pp[11].intersects(pp[20]) == False and pp[11].intersects(pp[21]) == False and pp[11].intersects(pp[22]) == False and pp[11].intersects(pp[23]) == False and
   pp[12].intersects(pp[13]) == False and pp[12].intersects(pp[14]) == False and pp[12].intersects(pp[15]) == False and pp[12].intersects(pp[16]) == False and pp[12].intersects(pp[17]) == False and pp[12].intersects(pp[18]) == False and pp[12].intersects(pp[19]) == False and pp[12].intersects(pp[20]) == False and pp[12].intersects(pp[21]) == False and pp[12].intersects(pp[22]) == False and pp[12].intersects(pp[23]) == False and
   pp[13].intersects(pp[14]) == False and pp[13].intersects(pp[15]) == False and pp[13].intersects(pp[16]) == False and pp[13].intersects(pp[17]) == False and pp[13].intersects(pp[18]) == False and pp[13].intersects(pp[19]) == False and pp[13].intersects(pp[20]) == False and pp[13].intersects(pp[21]) == False and pp[13].intersects(pp[22]) == False and pp[13].intersects(pp[23]) == False and
   pp[14].intersects(pp[15]) == False and pp[14].intersects(pp[16]) == False and pp[14].intersects(pp[17]) == False and pp[14].intersects(pp[18]) == False and pp[14].intersects(pp[19]) == False and pp[14].intersects(pp[20]) == False and pp[14].intersects(pp[21]) == False and pp[14].intersects(pp[22]) == False and pp[14].intersects(pp[23]) == False and
   pp[15].intersects(pp[16]) == False and pp[15].intersects(pp[17]) == False and pp[15].intersects(pp[18]) == False and pp[15].intersects(pp[19]) == False and pp[15].intersects(pp[20]) == False and pp[15].intersects(pp[21]) == False and pp[15].intersects(pp[22]) == False and pp[15].intersects(pp[23]) == False and
   pp[16].intersects(pp[17]) == False and pp[16].intersects(pp[18]) == False and pp[16].intersects(pp[19]) == False and pp[16].intersects(pp[20]) == False and pp[16].intersects(pp[21]) == False and pp[16].intersects(pp[22]) == False and pp[16].intersects(pp[23]) == False and
   pp[17].intersects(pp[18]) == False and pp[17].intersects(pp[19]) == False and pp[17].intersects(pp[20]) == False and pp[17].intersects(pp[21]) == False and pp[17].intersects(pp[22]) == False and pp[17].intersects(pp[23]) == False and
   pp[18].intersects(pp[19]) == False and pp[18].intersects(pp[20]) == False and pp[18].intersects(pp[21]) == False and pp[18].intersects(pp[22]) == False and pp[18].intersects(pp[23]) == False and
   pp[19].intersects(pp[20]) == False and pp[19].intersects(pp[21]) == False and pp[19].intersects(pp[22]) == False and pp[19].intersects(pp[23]) == False and
   pp[20].intersects(pp[21]) == False and pp[20].intersects(pp[22]) == False and pp[20].intersects(pp[23]) == False and
   pp[21].intersects(pp[22]) == False and pp[21].intersects(pp[23]) == False and pp[22].intersects(pp[23]) == False):
    f = -1
else:
    f = 1
 
"""
