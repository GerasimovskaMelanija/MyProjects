# %%
import numpy as np
import pandas as pd
from shapely.geometry import Point, Polygon
import random
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('jakobs1.xlsx')
data.head(6)
size = data.iloc[1]['Unnamed: 2']
width = data.iloc[2]['Unnamed: 4']
koordinati = [] 
for i in range(len(data.index)):
    if i >=4 :
        if pd.notnull(data.iloc[i]['Unnamed: 0']) == True:
            t = []
            x = []
            y = []
            for j in range(1,len(data.columns)):
                if pd.notnull(data.iloc[i]['Unnamed: ' + str(j)]) == True:
                    
                    x.append(data.iloc[i]['Unnamed: '+ str(j)])
                    y.append(data.iloc[i+1]['Unnamed: ' + str(j)])
            for m in range(len(x)):
                if m>0:
                    
                    t.append([x[m],y[m]])
            koordinati.append(t)
Poligoni = []
for i in range(len(koordinati)):
    Poligoni.append(Polygon(koordinati[i]))

# %%
data.head(6)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      name:        NaN    Jakobs1         NaN         NaN         NaN
# 1      size:        NaN         25         NaN         NaN         NaN
# 2    object:        NaN     width:         NaN        40.0         NaN
# 3         no        NaN        NaN         NaN         NaN         NaN
# 4          1          x          0         2.0         0.0         NaN
# 5        NaN          y          0         0.0         2.0         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN         NaN         NaN         NaN          NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN          NaN
# ...

# %%
site = []
while(len(site)<len(koordinati)):
    max = 0 
    for m in range(len(Poligoni)) :
        if m not in site:
            if Poligoni[m].area > max:
                max = Poligoni[m].area
                number = m

    site.append(number)
polygons = []
for i in site:
    polygons.append(koordinati[i])
print(len(polygons))
# Out:
# 25

# %%
def moveUp(poly1,poly2,poly11,poly22):
    min2 = poly2[0][1]
    for i in range(len(poly2)-1):
        if poly2[i+1][1] < min2:
            min2 = poly2[i+1][1]
    max1 = poly1[0][1] #naogjame max y koordinata na poligon1
    for i in range(len(poly1)-1):
        if poly1[i+1][1] > max1:
            max1 = poly1[i+1][1]
    
    rastojanie = max1 - min2 +3  #+20 ako sakame da ima prostor mal megju niv, no dokolku se dopiraat, togas samo +1 moze da se dodade
    for i in range(len(poly2)):
        poly2[i][1] = poly2[i][1] + rastojanie
    poly22 = Polygon(poly2)
    return poly1,poly2,poly11,poly22 
def najgolemo_yrastojanie(poly):
    miny = poly[0][1]
    for k in range(len(poly)-1):
        if poly[k+1][1] <miny:
            miny = poly[k+1][1]
    maxy = poly[0][1]
    for m in range(len(poly)-1):
        if poly[m+1][1] > maxy:
            maxy = poly[m+1][1]
    rastojanie = maxy - miny
    return rastojanie
postaveni=[]
koord_p=[]
up=[]
right=[]
koord_za_comp = []
pp=[]
for i in range(size):
    pp.append(Polygon(polygons[i])) #pp[0] = poligon na parce1 (kade sto se smesteni koordinati)

def min_x(poly):
    min_x = poly[0][0]
    for m in range(len(poly)-1):
        if poly[m+1][0] < min_x:
            min_x = poly[m+1][0]
    return min_x
def max_x(poly):
    max_x = poly[0][0]
    for k in range(len(poly)-1):
        if poly[k+1][0] > max_x:
            max_x = poly[k+1][0]
    return max_x
def min_y(poly):
    min_y = poly[0][1]
    for m in range(len(poly)-1):
        if poly[m+1][1] < min_y:
            min_y = poly[m+1][1]
    return min_y
def max_y(poly):
    max_y = poly[0][1]
    for k in range(len(poly)-1):
        if poly[k+1][1] > max_y:
            max_y = poly[k+1][1]
    return max_y
    
for i in range(0,2):
    #prvo naogjame min i max koordinati
    #go postavuvame prvoto parce vo (0,0)
    for k in range(len(polygons[i])):
        polygons[i][k][0] = polygons[i][k][0] - min_x(polygons[i])
    for k in range(len(polygons[i])):
        polygons[i][k][1] = polygons[i][k][1] - min_y(polygons[i])
    pp[i] = Polygon(polygons[i])
      
    if i == 1:
        if pp[0].intersects(pp[1]) == False:
            #print('Ne se secat prvoto i vtoroto parce')
            while(pp[0].intersects(pp[1]) == False and min_x(polygons[i]) >=0):
                for k in range(len(polygons[i])):
                    polygons[i][k][1] = polygons[i][k][1] - 1
            up[i-1] == 1
        #vtor poligon
        if pp[0].intersects(pp[1]):
            #print('Se secat prvoto i vtoroto parce')
            max_y1 = 0
            for k in range(len(polygons[i-1])):
                if polygons[i-1][k][1] > max_y1:
                    max_y1 = polygons[i-1][k][1] #max_y1 e max y koordinat ana prvo parce (parce i - 1)
            slobodno_rastojanie = width - max_y1
            if up[i-1] == 0 and slobodno_rastojanie>=najgolemo_yrastojanie(polygons[i]):
                moveUp(polygons[i-1], polygons[i],pp[i-1],pp[i])
                #print('Парчето 2 е придвижено нагоре')
                up[i-1] = 1
                
            if slobodno_rastojanie<najgolemo_yrastojanie(polygons[i]):
                #print('Parceto 2 ne moze da se postavi nad parce 1')
                for k in range(len(right)):
                    if right[k] == 0:
                        #zemi gi najdesni x i y koordinate na parce
                        max_x2 = 0
                        for l in range(len(polygons[k])):
                            if polygons[k][l][0] > max_x2:
                                max_x2 = polygons[k][l][0]
                                y_koord = polygons[k][l][1]
                        rastojaniex1 = max_x2 - min_x(polygons[i])
                        rastojaniey1 = min_y(polygons[k]) - min_y(polygons[i])
                        for j in range(len(polygons[i])):
                            polygons[i][j][0] = polygons[i][j][0] + rastojaniex1
                            polygons[i][j][1] = polygons[i][j][1] + rastojaniey1
                        right[k] = 1
                        
                        
    up.append(0)
    right.append(0)
    pp[i] = Polygon(polygons[i])
    postaveni.append(pp[i])
    koord_p.append(polygons[i]) 
    koord_za_comp.append(polygons[i])
    
    
for j in range(2,size):
    index_k = []
    i=j
    #print('Pocnuvame so postavuvanje na parce : ', j+1)
    GG=False
    TT=False
    for u in range(len(up)):
        
        if up[u] == 0 and GG == False:
            rastojanie1 = min_x(koord_p[u]) - min_x(polygons[j]) 
            rastojanie2 = max_y(koord_p[u]) - min_y(polygons[j]) 
            for k in range(len(polygons[j])):
                polygons[j][k][0] = polygons[j][k][0] + (rastojanie1 + 1)
                polygons[j][k][1] = polygons[j][k][1] + (rastojanie2 + 1)
            pp[j] = Polygon(polygons[j])
            if i == 2:
                
                if pp[0].intersects(pp[j]) == False and pp[1].intersects(pp[j]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad vtoro parce postaveno')
                    GG=True
                    up[u] = 1
                    
            if i == 3:
                
                if pp[0].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad treto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 4:
                
                
                if pp[0].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad cetvrto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 5:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad petto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 6:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad sesto parce postaveno')
                    GG=True
                    up[u] = 1   
            if i == 7:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad sedmo parce postaveno')
                    GG=True
                    up[u] = 1
                    
            if i == 8:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad osmo parce postaveno')
                    GG=True
                    up[u] = 1
                    
            if i == 9:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad devetto parce postaveno')
                    GG=True
                    up[u] = 1
                    
            if i == 10:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad desetto parce postaveno')
                    GG=True
                    up[u] = 1
                    
            if i == 11:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad edinaesto parce postaveno')
                    GG=True
                    up[u] = 1
                    
            if i == 12:
                TT=False
                if pp[0].intersects(pp[i]) == False  and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad dvanaesto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 13:
                TT=False
                if pp[0].intersects(pp[i]) == False  and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad trinaesto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 14:
                TT=False
                if pp[0].intersects(pp[i]) == False  and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad cetarnaesto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 15:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad petnaesto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 16:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad sesnaesto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 17:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad sedumnaesto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 18:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad osumnaesto parce postaveno')
                    GG=True
                    up[u] = 1 
            if i == 19:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad devetnaesto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 20:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad dvaesetto parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 21:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad dvaeset i prvo parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 22:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[21].intersects(pp[i]) == False and pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    #print('Treba da e nad dvaeset i vtoro parce postaveno')
                    GG=True
                    up[u] = 1
            if i == 23:
                TT=False
                if pp[0].intersects(pp[i]) == False and pp[22].intersects(pp[i]) == False and pp[21].intersects(pp[i]) == False and pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    
                    GG=True
                    up[u] = 1  
            if i == 24:
                TT=False
                if pp[23].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[22].intersects(pp[i]) == False and pp[21].intersects(pp[i]) == False and pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[10].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                    
                    GG=True
                    up[u] = 1  
    if GG == False:
        TT=False
        index_k = []
        if i == 2:
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 2:
                        if pp[0].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            right[k] = 1
                                    
                        else:
                            if max_y(polygons[i])<=width:
                                index_k.append(k)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True  :
                z = index_k[0]
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                        
                            
            

        if i == 3:
            index_k = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 3:
                        if pp[0].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            right[k] = 1
                                    
                        else:
                            if max_y(polygons[i])<=width:
                                index_k.append(k)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True and TT == False :
                z = index_k[0]
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z)
            
                    
        if i == 4:
            index_k4 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 4:
                        if pp[0].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            right[k] = 1
                                    
                        else:
                            if max_y(polygons[i])<=width:
                                #print('Cetvrto parce e vlezeno za index_k')
                                index_k4.append(k)
                                #print(index_k4)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT == False:
                z = index_k4[0]
                #print('Parce 5 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z)
                    
           
                    

        if i == 5:
            index_k5=[]
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 5:
                        if pp[0].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                index_k5.append(k)
                                #print(index_k5)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT == False and max_y(polygons[i])<=width:
                z = index_k5[0]
                #print('Parce 6 treba da se postavi desno od : ', z+1)

                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or  pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 30
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z)
                #break
            
                    

        if i == 6:
            index_k6 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 6:
                        i=j
                        if pp[0].intersects(pp[j]) == False and pp[5].intersects(pp[j]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                #print('Vlezeno e za parce 7 za index_k6')
                                index_k6.append(k)
                                #print(index_k6)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:
               # print('Index_k6:',index_k6)
                z = index_k6[0]
               # print('Parce 7 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[0].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True ):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z)
                    
            

        if i == 7:
            index_k7 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 7:
                        if pp[0].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                #print('Vlezeno e za parce 8 za index_k')
                                index_k7.append(k)
                                #print(index_k7)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:
                #print('Index_k7:', index_k7)
                z = index_k7[0]
                #print('Parce 8 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
            

        if i == 8:
            index_k8 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 8:
                        if pp[0].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('Devetto parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                               # print('Vlezeno e za parce 9 za index_k')
                                index_k8.append(k)
                                #print(index_k8)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k8[0]
                #print('Parce 9 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
            

        if i == 9:
            index_k9 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 9:
                        if pp[0].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('Deseto parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                               # print('Vlezeno e za parce 10 za index_k')
                                index_k9.append(k)
                                #print(index_k9)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k9[0]
                #print('Parce 10 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
            

        if i == 10:
            index_k10 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 10:
                        if pp[0].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('Edinaesto parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                #print('Vlezeno e za parce 11 za index_k')
                                index_k10.append(k)
                                #print(index_k10)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k10[0]
                #print('Parce 11 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
            

        if i == 11:
            index_k11 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 11:
                        if pp[0].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('Edinaesto parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                               # print('Vlezeno e za parce 11 za index_k')
                                index_k11.append(k)
                                #print(index_k11)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k11[0]
                #print('Parce 11 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
            

        if i == 12:
            index_k12 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 12:
                        if pp[0].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('Trinaesto parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                print('Vlezeno e za parce 13 za index_k')
                                index_k12.append(k)
                                #print(index_k12)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k12[0]
                #print('Parce 13 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 13:
            #ovoj e 14 parce
            index_k13 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 13:
                        if pp[0].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('Cetarnaesto parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                #print('Vlezeno e za parce 14 za index_k')
                                index_k13.append(k)
                                #print(index_k13)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k13[0]
                #print('Parce 14 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 14:
            #ovoj e 15 parce
            index_k14 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 14:
                        if pp[0].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('Petnaesto parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                print('Vlezeno e za parce 15 za index_k')
                                index_k14.append(k)
                                #print(index_k14)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k14[0]
                #print('Parce 15 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 15:
            #ovoj e 16 parce
            index_k15 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 15:
                        if pp[0].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('16 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                #print('Vlezeno e za parce 16 za index_k')
                                index_k15.append(k)
                                #print(index_k15)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k15[0]
                #print('Parce 16 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and max_y(pp[i])<=width):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 16:
            #ovoj e 17 parce
            index_k16 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 16:
                        if pp[0].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('17 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                #print('Vlezeno e za parce 17 za index_k')
                                index_k16.append(k)
                                #print(index_k16)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k16[0]
               # print('Parce 17 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 17:
            #ovoj e 18 parce
            index_k17 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 17:
                        if pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                            #print('18 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                                #print('Vlezeno e za parce 18 za index_k')
                                index_k17.append(k)
                                #print(index_k17)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k17[0]
                #print('Parce 18 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 18:
            #ovoj e 19 parce
            index_k18 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 18:
                        if pp[17].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('19 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                              #  print('Vlezeno e za parce 19 za index_k')
                                index_k18.append(k)
                                #print(index_k18)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k18[0]
               # print('Parce 19 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 19:
            #ovoj e 20 parce
            index_k19 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 19:
                        if pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('20 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                               # print('Vlezeno e za parce 20 za index_k')
                                index_k19.append(k)
                                #print(index_k19)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k19[0]
               # print('Parce 20 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 20:
            #ovoj e 21 parce
            index_k20 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 20:
                        if pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(koord_p[i])<=width :
                            TT=True
                           # print('21 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                              #  print('Vlezeno e za parce 21 za index_k')
                                index_k20.append(k)
                                #print(index_k20)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k20[0]
               # print('Parce 21 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 21:
            #ovoj e 22 parce
            index_k21 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 21:
                        if pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('22 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                              #  print('Vlezeno e za parce 22 za index_k')
                                index_k21.append(k)
                                #print(index_k21)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[20].intersects(pp[i]) ==True or  pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k21[0]
              #  print('Parce 22 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[20].intersects(pp[i]) ==True or pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 22:
            #ovoj e 23 parce
            index_k22 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 22:
                        if pp[21].intersects(pp[i]) == False and pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('23 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                               # print('Vlezeno e za parce 23 za index_k')
                                index_k22.append(k)
                                #print(index_k22)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[21].intersects(pp[i]) ==True or pp[20].intersects(pp[i]) ==True or  pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k22[0]
                #print('Parce 23 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[21].intersects(pp[i]) ==True or pp[20].intersects(pp[i]) ==True or pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
                #print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
        if i == 23:
            #ovoj e 24 parce
            index_k23 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 23:
                        if pp[22].intersects(pp[i]) == False and pp[21].intersects(pp[i]) == False and pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('24 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                               # print('Vlezeno e za parce 24 za index_k')
                                index_k23.append(k)
                                #print(index_k23)
                                TT = False
            if pp[0].intersects(pp[i]) == True or pp[22].intersects(pp[i]) ==True or pp[21].intersects(pp[i]) ==True or pp[20].intersects(pp[i]) ==True or  pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k23[0]
               # print('Parce 24 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[7].intersects(pp[i]) == True or pp[22].intersects(pp[i]) ==True or pp[21].intersects(pp[i]) ==True or pp[20].intersects(pp[i]) ==True or pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
                
        if i == 24:
            #ovoj e 25 parce
            index_k24 = []
            for k in range(len(right)):
                if right[k]== 0 and TT == False:
                    rastojanie1 = max_x(koord_p[k]) - min_x(polygons[j])
                    rastojanie2 = min_y(koord_p[k]) - min_y(polygons[j])
                    for m in range(len(polygons[j])):
                        polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                        polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                    pp[j] = Polygon(polygons[j])
                    if i == 24:
                        if pp[23].intersects(pp[i]) == False and pp[22].intersects(pp[i]) == False and pp[21].intersects(pp[i]) == False and pp[20].intersects(pp[i]) == False and pp[19].intersects(pp[i]) == False and pp[18].intersects(pp[i]) == False and pp[17].intersects(pp[i]) == False and pp[0].intersects(pp[i]) == False and pp[16].intersects(pp[i]) == False and pp[15].intersects(pp[i]) == False and pp[14].intersects(pp[i]) == False and pp[13].intersects(pp[i]) == False and pp[12].intersects(pp[i]) == False and pp[11].intersects(pp[i]) == False and  pp[10].intersects(pp[i]) == False and pp[9].intersects(pp[i]) == False and pp[8].intersects(pp[i]) == False and pp[7].intersects(pp[i]) == False and pp[6].intersects(pp[i]) == False and pp[5].intersects(pp[i]) == False and pp[4].intersects(pp[i]) == False and pp[1].intersects(pp[i]) == False and pp[2].intersects(pp[i]) == False and pp[3].intersects(pp[i]) == False and max_y(polygons[i])<=width :
                            TT=True
                           # print('25 parce treba da e desno do ', k)
                            right[k] = 1

                        else:
                            if max_y(polygons[i])<=width:
                               # print('Vlezeno e za parce 24 za index_k')
                                index_k24.append(k)
                                #print(index_k23)
                                TT = False
            if pp[23].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[22].intersects(pp[i]) ==True or pp[21].intersects(pp[i]) ==True or pp[20].intersects(pp[i]) ==True or  pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[10].intersects(pp[i]) ==True or  pp[9].intersects(pp[i]) == True or pp[8].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True and TT==False:

                z = index_k24[0]
               # print('Parce 24 treba da se postavi desno od : ', z+1)
                rastojanie1 = max_x(koord_p[z]) - min_x(polygons[j])
                rastojanie2 = min_y(koord_p[z]) - min_y(polygons[j])
                for m in range(len(polygons[j])):
                    polygons[j][m][0] = polygons[j][m][0] + rastojanie1
                    polygons[j][m][1] = polygons[j][m][1] + rastojanie2
                while(pp[23].intersects(pp[i]) == True or pp[7].intersects(pp[i]) == True or pp[22].intersects(pp[i]) ==True or pp[21].intersects(pp[i]) ==True or pp[20].intersects(pp[i]) ==True or pp[19].intersects(pp[i]) ==True or pp[18].intersects(pp[i]) ==True or pp[17].intersects(pp[i]) ==True or pp[16].intersects(pp[i]) == True or pp[15].intersects(pp[i]) ==True or pp[14].intersects(pp[i]) ==True or pp[13].intersects(pp[i]) ==True or pp[12].intersects(pp[i]) ==True or pp[11].intersects(pp[i]) ==True or pp[9].intersects(pp[i]) == True or pp[10].intersects(pp[i]) ==True or pp[8].intersects(pp[i]) == True or pp[0].intersects(pp[i]) == True or pp[6].intersects(pp[i]) == True or pp[1].intersects(pp[i]) == True or pp[5].intersects(pp[i]) == True or pp[4].intersects(pp[i]) == True or pp[2].intersects(pp[i]) == True or pp[3].intersects(pp[i]) == True):
                    for k in range(len(polygons[j])):
                        polygons[j][k][0] = polygons[j][k][0] + 1
                    pp[j] = Polygon(polygons[j])
                right[z] = 1
               # print('Parce',  j + 1,' e postaveno desno od :',z + 1)
                #break
    print(i)
    print(pp[i].bounds)
    if pp[i].bounds[3]>width:
        while(max_y(polygons[i]))>width:
            for m in range(len(polygons[i])):
                polygons[i][m][1] = polygons[i][m][1] - 1
                polygons[i][m][0] = polygons[i][m][0] + 0.3
                
    up.append(0)
    right.append(0)
    pp[j] = Polygon(polygons[j])
    postaveni.append(pp[j])
    koord_p.append(polygons[j])
    koord_za_comp.append(polygons[i])

p11 = koord_p[0]
p22 = koord_p[1]
p33 = koord_p[2]
p44 = koord_p[3]
p55 = koord_p[4]
p66 = koord_p[5]
p77 = koord_p[6]
p88 = koord_p[7]
p99 = koord_p[8]
p1010 = koord_p[9]
p1111 = koord_p[10]
p1212 = koord_p[11]                            
p1313 = koord_p[12]
p1414 = koord_p[13]
p1515 = koord_p[14]
p1616 = koord_p[15]
p1717 = koord_p[16]
p1818 = koord_p[17]
p1919 = koord_p[18]
p2020 = koord_p[19]
p2121 = koord_p[20]
p2222 = koord_p[21]
p2323 = koord_p[22]
p2424 = koord_p[23] 
p2525 = koord_p[24] 
p11.append(p11[0])
p22.append(p22[0])
p33.append(p33[0])
p44.append(p44[0])
p55.append(p55[0])
p66.append(p66[0])
p77.append(p77[0])
p88.append(p88[0])
p99.append(p99[0])
p1010.append(p1010[0])
p1111.append(p1111[0])
p1212.append(p1212[0])                            
p1313.append(p1313[0])
p1414.append(p1414[0])
p1515.append(p1515[0])
p1616.append(p1616[0])
p1717.append(p1717[0])
p1818.append(p1818[0])
p1919.append(p1919[0])
p2020.append(p2020[0])
p2121.append(p2121[0])
p2222.append(p2222[0])
p2323.append(p2323[0])
p2424.append(p2424[0])
p2525.append(p2525[0])
x111, y111 = zip(*p11)
x222, y222 = zip(*p22)
x333, y333 = zip(*p33)
x444, y444 = zip(*p44)
x555, y555 = zip(*p55)
x666, y666 = zip(*p66)
x777, y777 = zip(*p77)
x888, y888 = zip(*p88)
x999, y999 = zip(*p99)
x1010, y1010 = zip(*p1010)
x1111, y1111 = zip(*p1111)
x1212, y1212 = zip(*p1212)
x1313, y1313 = zip(*p1313)
x1414, y1414 = zip(*p1414)
x1515, y1515 = zip(*p1515)
x1616, y1616 = zip(*p1616)
x1717, y1717 = zip(*p1717)
x1818, y1818 = zip(*p1818)
x1919, y1919 = zip(*p1919)
x2020, y2020 = zip(*p2020)
x2121, y2121 = zip(*p2121)
x2222, y2222 = zip(*p2222)
x2323, y2323 = zip(*p2323)
x2424, y2424 = zip(*p2424)
x2525, y2525 = zip(*p2525)
plt.figure(figsize = (8.0, 8.0))
plt.plot(x111,y111, 'b' ,label ='1' )
plt.plot(x222,y222, 'g',label ='2')
plt.plot(x333,y333, 'r',label ='3')
plt.plot(x444,y444,label ='4')
plt.plot(x555,y555, 'y', label ='5')
plt.plot(x666,y666 ,label ='6')
plt.plot(x777,y777 ,label ='7')
plt.plot(x888,y888 ,label ='8')
plt.plot(x999,y999 ,label ='9')
plt.plot(x1010,y1010 ,label ='10')
plt.plot(x1111,y1111, 'r' ,label ='11')
plt.plot(x1212,y1212,label ='12')
plt.plot(x1313,y1313,label ='13')
plt.plot(x1414,y1414,label ='14')
plt.plot(x1515,y1515,label ='15')
plt.plot(x1616,y1616,label ='16')
plt.plot(x1717,y1717,label ='17')
plt.plot(x1818,y1818,label ='18')
plt.plot(x1919,y1919,label ='19')
plt.plot(x2020,y2020,label ='20')
plt.plot(x2121,y2121,label ='21')
plt.plot(x2222,y2222,label ='22')
plt.plot(x2323,y2323,label ='23')                             
plt.plot(x2424,y2424,label ='24') 
plt.plot(x2525,y2525,label ='25') 
#plt.legend()
plt.show()
# Out:
# 2
# (1.0, 16.0, 7.0, 22.0)
# 3
# (2.0, 23.0, 8.0, 29.0)
# 4
# (3.0, 30.0, 9.0, 36.0)
# 5
# (38.0, 0.0, 43.0, 5.0)
# 6
# (39.0, 6.0, 44.0, 11.0)
# 7
# (40.0, 12.0, 46.0, 18.0)
# 8
# (41.0, 19.0, 47.0, 25.0)
# 9
# (4.0, 37.0, 10.0, 40.0)
# 10
# (42.0, 26.0, 46.0, 30.0)
# 11
# (43.0, 31.0, 50.0, 35.0)
# 12
# (44.0, 36.0, 50.0, 39.0)
# 13
# (7.0, 16.0, 12.0, 21.0)
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# Vlezeno e za parce 15 za index_k
# 14
# (7.0, 9.0, 11.0, 13.0)
# 15
# (9.0, 23.0, 14.0, 25.0)
# 16
# (10.0, 26.0, 16.0, 29.0)
# 17
# (8.0, 14.0, 12.0, 18.0)
# 18
# (11.0, 30.0, 16.0, 32.0)
# 19
# (12.0, 33.0, 16.0, 35.0)
# 20
# (13.0, 36.0, 16.0, 39.0)
# 21
# ...

# %%
for l in range(len(koord_p)):
    koord_p[l] = koord_p[l][0:-1]
for m in range(len(koord_p)):
    if min_x(koord_p[m]) > 0:
        broj1 = 0
        broj2 = 0
        
        for k in range(len(koord_p[m])):
            koord_p[m][k][0] = koord_p[m][k][0] - 1
        pp[m] = Polygon(koord_p[m])
        for i in range(len(koord_p)):
            if i != m :
                if pp[i].intersects(pp[m]):
                    broj1 = broj1 + 1

        if broj1 != 0 :
            for k in range(len(koord_p[m])):
                koord_p[m][k][0] = koord_p[m][k][0] + 1
            pp[m] = Polygon(koord_p[m])
        else:
            print('Moze da go pomestime prvicno na levo parceto : ',m)
                    
     
            while (broj1 == 0 and min_x(koord_p[m]) >0):
                for k in range(len(koord_p[m])):
                    koord_p[m][k][0] = koord_p[m][k][0] - 1
                pp[m] = Polygon(koord_p[m])
                for i in range(len(koord_p)):
                    if i != m :
                        if pp[i].intersects(pp[m]):
                            broj1 = broj1 + 1
                if broj1 > 0 :
                    for k in range(len(koord_p[m])):
                        koord_p[m][k][0] = koord_p[m][k][0] + 1
                    pp[m] = Polygon(koord_p[m])
        if min_y(koord_p[m])>0:
            for k in range(len(koord_p[m])):
                koord_p[m][k][1] = koord_p[m][k][1] - 1
            pp[m] = Polygon(koord_p[m])
            for j in range(len(koord_p)):
                if j !=m:
                    if pp[j].intersects(pp[m]):
                        broj2 = broj2 +1
            if broj2 != 0 : 
                for k in range(len(koord_p[m])):
                    koord_p[m][k][1] = koord_p[m][k][1] + 1
                pp[m] = Polygon(koord_p[m])
            else :
                print('Moze da go pomestime parceto nadolu sega(prethodno bese na levo)',m)
                while (broj2 == 0 and min_y(koord_p[m]) >0):
                    for k in range(len(koord_p[m])):
                        koord_p[m][k][1] =koord_p[m][k][1] - 1
                    pp[m] = Polygon(koord_p[m])
                    for j in range(len(koord_p)):
                        if j !=m:
                            if pp[j].intersects(pp[m]):
                                broj2 = broj2 +1
                    if broj2 > 0 :
                        for k in range(len(koord_p[m])):
                            koord_p[m][k][1] = koord_p[m][k][1] + 1
                        pp[m] = Polygon(koord_p[m])

        if min_x(koord_p[m]) > 0:

            broj11 = 0

            for k in range(len(koord_p[m])):
                koord_p[m][k][0] = koord_p[m][k][0] - 1
            pp[m] = Polygon(koord_p[m])
            for i in range(len(koord_p)):
                if i != m :
                    if pp[i].intersects(pp[m]):
                        broj11 = broj11 + 1

            if broj11 != 0 :
                for k in range(len(koord_p[m])):
                    koord_p[m][k][0] = koord_p[m][k][0] + 1
                pp[m] = Polygon(koord_p[m])
            else:

                while (broj11 == 0 and min_x(koord_p[m]) >0):
                    for k in range(len(koord_p[m])):
                        koord_p[m][k][0] = koord_p[m][k][0] - 1
                    pp[m] = Polygon(koord_p[m])
                    for i in range(len(koord_p)):
                        if i != m :
                            if pp[i].intersects(pp[m]):
                                broj11 = broj11 + 1
                    if broj11 > 0 :
                        for k in range(len(koord_p[m])):
                            koord_p[m][k][0] = koord_p[m][k][0] + 1
                        pp[m] = Polygon(koord_p[m])

      
            
    if min_y(koord_p[m]) > 0:
        broj3 = 0
        broj4 = 0
        for k in range(len(koord_p[m])):
            koord_p[m][k][1] = koord_p[m][k][1] - 1
            
        pp[m] = Polygon(koord_p[m])
        for i in range(len(koord_p)):
            if i!=m:
                if pp[i].intersects(pp[m]):
                    broj3 = broj3 + 1
        if broj3 != 0 : 
            for k in range(len(koord_p[m])):
              
                koord_p[m][k][1] = koord_p[m][k][1] + 1
            pp[m] = Polygon(koord_p[m])  
        else:
            print('Moze da go pomestime prvicno nadolu parceto',m)
            while(broj3 == 0 and min_y(koord_p[m]) >0):
                for k in range(len(koord_p[m])):
                    koord_p[m][k][1] = koord_p[m][k][1] - 1
                pp[m] = Polygon(koord_p[m])
                for i in range(len(koord_p)):
                    if i!=m:
                        if pp[i].intersects(pp[m]):
                            broj3 = broj3 + 1
                if broj3 > 0 :
                    for k in range(len(koord_p[m])):
                        koord_p[m][k][1] = koord_p[m][k][1] + 1
                    pp[m] = Polygon(koord_p[m])
        if min_x(koord_p[0])>0:
            for k in range(len(koord_p[m])):
                koord_p[m][k][0] = koord_p[m][k][0] - 1
            pp[m] = Polygon(koord_p[m])
            for j in range(len(koord_p)):
                if j!=m:
                    if pp[j].intersects(pp[m]):
                        broj4 = broj4 + 1
            if broj4 != 0:
                for k in range(len(koord_p[m])):
                    koord_p[m][k][0] = koord_p[m][k][0] + 1
                pp[m] = Polygon(koord_p[m])    
            else:
                print('Moze da go pomestime sega na levo parceto, otkako bese nadolu pomesteno', m)
                while (broj4 == 0 and min_x(koord_p[m]) >0):
                    for k in range(len(koord_p[m])):
                        koord_p[m][k][0] =koord_p[m][k][0] - 1
                    pp[m] = Polygon(koord_p[m])
                    for j in range(len(koord_p)):
                        if j!=m:
                            if pp[j].intersects(pp[m]):
                                broj4 = broj4 + 1
                    if broj4 > 0 :
                        for k in range(len(koord_p[m])):
                            koord_p[m][k][0] = koord_p[m][k][0] + 1
                        pp[m] = Polygon(koord_p[m])

        if min_y(koord_p[m]) > 0:

            broj33 = 0
            for k in range(len(koord_p[m])):
                koord_p[m][k][1] = koord_p[m][k][1] - 1

            pp[m] = Polygon(koord_p[m])
            for i in range(len(koord_p)):
                if i!=m:
                    if pp[i].intersects(pp[m]):
                        broj33 = broj33 + 1
            if broj33 != 0 : 
                for k in range(len(koord_p[m])):

                    koord_p[m][k][1] = koord_p[m][k][1] + 1
                pp[m] = Polygon(koord_p[m])  
            else:
                print('Moze da go pomestime prvicno nadolu parceto',m)
                while(broj33 == 0 and min_y(koord_p[m]) >0):
                    for k in range(len(koord_p[m])):
                        koord_p[m][k][1] = koord_p[m][k][1] - 1
                    pp[m] = Polygon(koord_p[m])
                    for i in range(len(koord_p)):
                        if i!=m:
                            if pp[i].intersects(pp[m]):
                                broj33 = broj33 + 1
                    if broj33 > 0 :
                        for k in range(len(koord_p[m])):
                            koord_p[m][k][1] = koord_p[m][k][1] + 1
                        pp[m] = Polygon(koord_p[m])
# Out:
# Moze da go pomestime prvicno nadolu parceto 1
# Moze da go pomestime prvicno na levo parceto :  2
# Moze da go pomestime parceto nadolu sega(prethodno bese na levo) 2
# Moze da go pomestime prvicno na levo parceto :  3
# Moze da go pomestime parceto nadolu sega(prethodno bese na levo) 3
# Moze da go pomestime prvicno na levo parceto :  4
# Moze da go pomestime parceto nadolu sega(prethodno bese na levo) 4
# Moze da go pomestime prvicno na levo parceto :  5
# Moze da go pomestime prvicno na levo parceto :  6
# Moze da go pomestime prvicno na levo parceto :  7
# Moze da go pomestime prvicno na levo parceto :  8
# Moze da go pomestime prvicno na levo parceto :  9
# Moze da go pomestime parceto nadolu sega(prethodno bese na levo) 9
# Moze da go pomestime prvicno na levo parceto :  10
# Moze da go pomestime parceto nadolu sega(prethodno bese na levo) 10
# Moze da go pomestime prvicno na levo parceto :  11
# Moze da go pomestime prvicno na levo parceto :  12
# ...

# %%
p11 = koord_p[0]
p22 = koord_p[1]
p33 = koord_p[2]
p44 = koord_p[3]
p55 = koord_p[4]
p66 = koord_p[5]
p77 = koord_p[6]
p88 = koord_p[7]
p99 = koord_p[8]
p1010 = koord_p[9]
p1111 = koord_p[10]
p1212 = koord_p[11]                            
p1313 = koord_p[12]
p1414 = koord_p[13]
p1515 = koord_p[14]
p1616 = koord_p[15]
p1717 = koord_p[16]
p1818 = koord_p[17]
p1919 = koord_p[18]
p2020 = koord_p[19]
p2121 = koord_p[20]
p2222 = koord_p[21]
p2323 = koord_p[22]
p2424 = koord_p[23] 
p2525 = koord_p[24] 
p11.append(p11[0])
p22.append(p22[0])
p33.append(p33[0])
p44.append(p44[0])
p55.append(p55[0])
p66.append(p66[0])
p77.append(p77[0])
p88.append(p88[0])
p99.append(p99[0])
p1010.append(p1010[0])
p1111.append(p1111[0])
p1212.append(p1212[0])                            
p1313.append(p1313[0])
p1414.append(p1414[0])
p1515.append(p1515[0])
p1616.append(p1616[0])
p1717.append(p1717[0])
p1818.append(p1818[0])
p1919.append(p1919[0])
p2020.append(p2020[0])
p2121.append(p2121[0])
p2222.append(p2222[0])
p2323.append(p2323[0])
p2424.append(p2424[0])
p2525.append(p2525[0])
x111, y111 = zip(*p11)
x222, y222 = zip(*p22)
x333, y333 = zip(*p33)
x444, y444 = zip(*p44)
x555, y555 = zip(*p55)
x666, y666 = zip(*p66)
x777, y777 = zip(*p77)
x888, y888 = zip(*p88)
x999, y999 = zip(*p99)
x1010, y1010 = zip(*p1010)
x1111, y1111 = zip(*p1111)
x1212, y1212 = zip(*p1212)
x1313, y1313 = zip(*p1313)
x1414, y1414 = zip(*p1414)
x1515, y1515 = zip(*p1515)
x1616, y1616 = zip(*p1616)
x1717, y1717 = zip(*p1717)
x1818, y1818 = zip(*p1818)
x1919, y1919 = zip(*p1919)
x2020, y2020 = zip(*p2020)
x2121, y2121 = zip(*p2121)
x2222, y2222 = zip(*p2222)
x2323, y2323 = zip(*p2323)
x2424, y2424 = zip(*p2424)
x2525, y2525 = zip(*p2525)
plt.figure(figsize = (8.0, 8.0))
plt.plot(x111,y111, 'b' ,label ='1' )
plt.plot(x222,y222, 'g',label ='2')
plt.plot(x333,y333, 'r',label ='3')
plt.plot(x444,y444,label ='4')
plt.plot(x555,y555, 'y', label ='5')
plt.plot(x666,y666 ,label ='6')
plt.plot(x777,y777 ,label ='7')
plt.plot(x888,y888 ,label ='8')
plt.plot(x999,y999 ,label ='9')
plt.plot(x1010,y1010 ,label ='10')
plt.plot(x1111,y1111, 'r' ,label ='11')
plt.plot(x1212,y1212,label ='12')
plt.plot(x1313,y1313,label ='13')
plt.plot(x1414,y1414,label ='14')
plt.plot(x1515,y1515,label ='15')
plt.plot(x1616,y1616,label ='16')
plt.plot(x1717,y1717,label ='17')
plt.plot(x1818,y1818,label ='18')
plt.plot(x1919,y1919,label ='19')
plt.plot(x2020,y2020,label ='20')
plt.plot(x2121,y2121,label ='21')
plt.plot(x2222,y2222,label ='22')
plt.plot(x2323,y2323,label ='23')                             
plt.plot(x2424,y2424,label ='24') 
plt.plot(x2525,y2525,label ='25') 
#plt.legend()
plt.show()

# %%
for i in range(len(koord_p)):
    print('Go pomestuvame sega parce broj',i)
    koord_p[i] = koord_p[i][:-1]
    ne_se_sece = True
    broj = 0
    while(ne_se_sece == True) :
        
        if min_x(koord_p[i]) == 0:
            ne_se_sece = False
        else:
            for k in range(len(koord_p[i])):
                koord_p[i][k][0] = koord_p[i][k][0] - 1
            pp[i] = Polygon(koord_p[i])
            
            for j in range(size):
                if j != i :
                    print(str(j) + ' e razlicno od '+ str(i))
                    if pp[j].intersects(pp[i]) == True:
                        broj = broj + 1
            if broj>0:
                ne_se_sece = False
                for k in range(len(koord_p[i])):
                    koord_p[i][k][0] = koord_p[i][k][0] + 1
                pp[i] = Polygon(koord_p[i])
# Out:
# Go pomestuvame sega parce broj 0
# Go pomestuvame sega parce broj 1
# Go pomestuvame sega parce broj 2
# Go pomestuvame sega parce broj 3
# Go pomestuvame sega parce broj 4
# Go pomestuvame sega parce broj 5
# 0 e razlicno od 5
# 1 e razlicno od 5
# 2 e razlicno od 5
# 3 e razlicno od 5
# 4 e razlicno od 5
# 6 e razlicno od 5
# 7 e razlicno od 5
# 8 e razlicno od 5
# 9 e razlicno od 5
# 10 e razlicno od 5
# 11 e razlicno od 5
# 12 e razlicno od 5
# 13 e razlicno od 5
# 14 e razlicno od 5
# 15 e razlicno od 5
# 16 e razlicno od 5
# 17 e razlicno od 5
# 18 e razlicno od 5
# 19 e razlicno od 5
# 20 e razlicno od 5
# 21 e razlicno od 5
# 22 e razlicno od 5
# 23 e razlicno od 5
# 24 e razlicno od 5
# Go pomestuvame sega parce broj 6
# 0 e razlicno od 6
# 1 e razlicno od 6
# 2 e razlicno od 6
# 3 e razlicno od 6
# 4 e razlicno od 6
# 5 e razlicno od 6
# 7 e razlicno od 6
# 8 e razlicno od 6
# 9 e razlicno od 6
# 10 e razlicno od 6
# 11 e razlicno od 6
# 12 e razlicno od 6
# ...

# %%
p11 = koord_p[0]
p22 = koord_p[1]
p33 = koord_p[2]
p44 = koord_p[3]
p55 = koord_p[4]
p66 = koord_p[5]
p77 = koord_p[6]
p88 = koord_p[7]
p99 = koord_p[8]
p1010 = koord_p[9]
p1111 = koord_p[10]
p1212 = koord_p[11]                            
p1313 = koord_p[12]
p1414 = koord_p[13]
p1515 = koord_p[14]
p1616 = koord_p[15]
p1717 = koord_p[16]
p1818 = koord_p[17]
p1919 = koord_p[18]
p2020 = koord_p[19]
p2121 = koord_p[20]
p2222 = koord_p[21]
p2323 = koord_p[22]
p2424 = koord_p[23] 
p2525 = koord_p[24] 
p11.append(p11[0])
p22.append(p22[0])
p33.append(p33[0])
p44.append(p44[0])
p55.append(p55[0])
p66.append(p66[0])
p77.append(p77[0])
p88.append(p88[0])
p99.append(p99[0])
p1010.append(p1010[0])
p1111.append(p1111[0])
p1212.append(p1212[0])                            
p1313.append(p1313[0])
p1414.append(p1414[0])
p1515.append(p1515[0])
p1616.append(p1616[0])
p1717.append(p1717[0])
p1818.append(p1818[0])
p1919.append(p1919[0])
p2020.append(p2020[0])
p2121.append(p2121[0])
p2222.append(p2222[0])
p2323.append(p2323[0])
p2424.append(p2424[0])
p2525.append(p2525[0])
x111, y111 = zip(*p11)
x222, y222 = zip(*p22)
x333, y333 = zip(*p33)
x444, y444 = zip(*p44)
x555, y555 = zip(*p55)
x666, y666 = zip(*p66)
x777, y777 = zip(*p77)
x888, y888 = zip(*p88)
x999, y999 = zip(*p99)
x1010, y1010 = zip(*p1010)
x1111, y1111 = zip(*p1111)
x1212, y1212 = zip(*p1212)
x1313, y1313 = zip(*p1313)
x1414, y1414 = zip(*p1414)
x1515, y1515 = zip(*p1515)
x1616, y1616 = zip(*p1616)
x1717, y1717 = zip(*p1717)
x1818, y1818 = zip(*p1818)
x1919, y1919 = zip(*p1919)
x2020, y2020 = zip(*p2020)
x2121, y2121 = zip(*p2121)
x2222, y2222 = zip(*p2222)
x2323, y2323 = zip(*p2323)
x2424, y2424 = zip(*p2424)
x2525, y2525 = zip(*p2525)
plt.figure(figsize = (8.0, 8.0))
plt.plot(x111,y111, 'b' ,label ='1' )
plt.plot(x222,y222, 'g',label ='2')
plt.plot(x333,y333, 'r',label ='3')
plt.plot(x444,y444,label ='4')
plt.plot(x555,y555, 'y', label ='5')
plt.plot(x666,y666 ,label ='6')
plt.plot(x777,y777 ,label ='7')
plt.plot(x888,y888 ,label ='8')
plt.plot(x999,y999 ,label ='9')
plt.plot(x1010,y1010 ,label ='10')
plt.plot(x1111,y1111, 'r' ,label ='11')
plt.plot(x1212,y1212,label ='12')
plt.plot(x1313,y1313,label ='13')
plt.plot(x1414,y1414,label ='14')
plt.plot(x1515,y1515,label ='15')
plt.plot(x1616,y1616,label ='16')
plt.plot(x1717,y1717,label ='17')
plt.plot(x1818,y1818,label ='18')
plt.plot(x1919,y1919,label ='19')
plt.plot(x2020,y2020,label ='20')
plt.plot(x2121,y2121,label ='21')
plt.plot(x2222,y2222,label ='22')
plt.plot(x2323,y2323,label ='23')                             
plt.plot(x2424,y2424,label ='24') 
plt.plot(x2525,y2525,label ='25') 
#plt.legend()
plt.show()

# %%
max_w = []
for i in range(len(koord_p)):
    max_w.append(max_x(koord_p[i]))
print(max_w)
m = 0
for j in range(len(max_w)):
    if max_w[j] > m:
        m = max_w[j]
print(m)
# Out:
# [8.0, 6.0, 6.0, 6.0, 6.0, 14.0, 17.0, 19.0, 19.0, 6.0, 22.0, 21.0, 20.0, 10.0, 11.0, 12.0, 11.0, 11.0, 11.0, 10.0, 10.0, 14.0, 14.0, 16.0, 13.0]
# 22.0

# %%
import phidl.geometry as pg
from phidl import quickplot as qp
from phidl import Device
x = [ [] for _ in range(size) ]
y = [ [] for _ in range(size) ]

    
for i in range(len(koordinati)):
    for k in range(len(koordinati[i])):
        x[i].append(koordinati[i][k][0])
        y[i].append(koordinati[i][k][1])
for m in range(len(x)):
    x[m] = tuple(x[m])
    y[m] = tuple(y[m])
D = [ [] for _ in range(size) ]
for i in range(size):
    D[i] = Device('Полигони')
for m in range(len(koordinati)):
    poly1 = D[m].add_polygon([x[m],y[m]])
m = pg.packer(D, spacing = 0.01, aspect_ratio = (1,2), max_size = (18,width), density = 1.01, sort_by_area = True, verbose = False)
D_x = m[0]
qp(m)

# %%
D_x.xmax
# Out:
# 17.02505
