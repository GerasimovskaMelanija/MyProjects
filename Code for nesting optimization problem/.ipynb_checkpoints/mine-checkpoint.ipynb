# %%
import pandas as pd

dighe1=pd.read_csv('dighe1.csv')
print (dighe1)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0       name:        NaN     Albano         NaN         NaN         NaN
# 1       size:        NaN         24         NaN         NaN         NaN
# 2     object:        NaN     width:      4900.0         NaN         NaN
# 3         no.   quantity        NaN         NaN         NaN         NaN
# 4           1          2          x         0.0       966.0      1983.0
# 5         NaN        NaN          y        86.0       142.0         0.0
# 6           2          2          x         0.0      3034.0      3034.0
# 7         NaN        NaN          y         0.0         0.0       261.0
# 8           3          4          x         0.0      1761.0      2183.0
# 9         NaN        NaN          y       173.0         0.0       650.0
# 10          4          4          x        74.0       870.0      1666.0
# 11        NaN        NaN          y         0.0       119.0         0.0
# ...
